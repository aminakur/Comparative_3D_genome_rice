# %% [markdown]
# # Visualizing TAD-rich and TAD-poor windows

# %% [markdown]
# 5kb TADs, 1Mb windows. Median TAD coverage = 0.21. Example windows
# TADs from file TADs_5kb_windowed_merged_overlaps_pr.bed

# %%
import coolbox
from coolbox.api import *

# %%
#0.005 coverage

cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr01:8200000-9200000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)

# %%
#0 coverage
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr01:7800000-8800000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)
# Out:
# [WARNING:plot.py:486 -            plot_tads()] No regions found for Coverage TAD.20.

# %%
#0.31
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr12:26100000-27100000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)

# %%
#0.565
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr01:11300000-12250000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)
# Out:
# [WARNING:plot.py:486 -            plot_tads()] No regions found for Coverage TAD.7.

# %%
#0.93
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr12:2100000-3100000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)
# Out:
# [WARNING:plot.py:486 -            plot_tads()] No regions found for Coverage TAD.4.

# %%
#0.865
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr12:2200000-3200000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)

# %%
#0.295
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr12:700000-1700000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)

# %% [markdown]
# ## Plotting a region with and without TADs as an example

# %%
#x coverage
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr01:24600000-26350000"

frame = XAxis() + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs')
    #TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)

# %%
#x coverage
cool = '/scratch/ak8725/az_mrg/az5kb.cool'
tads = '/scratch/ak8725/az_mrg/TADs_5kb_two_tools_intersect_80.bed'
test_region = "chr01:24600000-26350000"

frame = XAxis() + \
    InsuScore(cool, style='window') + Title("IS window_size=20") + Spacer(0.2) + \
    HiCMat(cool, style='window', depth_ratio=0.3) + Title('TADs') + \
    TADCoverage(tads, border_only=True, border_style = 'solid', border_color = 'black', alpha=1.0)

frame.plot(test_region)
